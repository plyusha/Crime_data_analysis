# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import dateutil

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
nyc_rental_load = "Resources/Neighborhood_Zri_AllHomesPlusMultifamily.csv"
nyc_rental_data=pd.read_csv(nyc_rental_load)
nyc_mean_price_sales = "Resources/nyc_mean_price_per_sqft.csv"
nyc_price_per_sqft = pd.read_csv(nyc_mean_price_sales)

# %%
nyc_rental_data.head()
# Out:
#    RegionID        RegionName         City State  \
# 0    274772  Northeast Dallas       Dallas    TX
# 1    192689          Paradise    Las Vegas    NV
# 2    112345          Maryvale      Phoenix    AZ
# 3    270958   Upper West Side     New York    NY
# 4     27080      Sherman Oaks  Los Angeles    CA
#
#                             Metro   CountyName  SizeRank  2010-11  2010-12  \
# 0               Dallas-Fort Worth       Dallas         1   1322.0   1340.0
# 1                       Las Vegas        Clark         2   1167.0   1160.0
# 2                         Phoenix     Maricopa         3    895.0    894.0
# 3                        New York     New York         4      NaN      NaN
# 4  Los Angeles-Long Beach-Anaheim  Los Angeles         5   2698.0   2705.0
#
#    2011-01   ...     2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0   1346.0   ...        1817     1815     1803     1790     1776     1763
# ...

# %%
manhattan_rent = nyc_rental_data[nyc_rental_data["CountyName"]=="New York"]

# %%
manhattan_rent_mean = manhattan_rent.drop(columns=["RegionID","RegionName","City","State","Metro","SizeRank","CountyName"]).mean()
manhattan_rent_mean.dropna()
# Out:
# 2011-12    3034.115385
# 2012-01    3016.884615
# 2012-02    3021.461538
# 2012-03    3022.807692
# 2012-04    3040.461538
# 2012-05    3052.846154
# 2012-06    3058.961538
# 2012-07    3069.346154
# 2012-08    3096.076923
# 2012-09    3126.730769
# 2012-10    3139.153846
# 2012-11    3130.961538
# 2012-12    3132.076923
# 2013-01    3123.115385
# 2013-02    3115.000000
# 2013-03    3101.923077
# 2013-04    3120.692308
# 2013-05    3163.153846
# 2013-06    3202.769231
# 2013-07    3211.923077
# 2013-08    3192.115385
# 2013-09    3203.538462
# 2013-10    3233.692308
# 2013-11    3271.615385
# 2013-12    3296.000000
# 2014-01    3316.038462
# 2014-02    3333.500000
# 2014-03    3326.115385
# 2014-04    3324.115385
# 2014-05    3311.000000
#               ...
# 2016-02    3777.423077
# 2016-03    3813.076923
# 2016-04    3845.461538
# 2016-05    3848.846154
# 2016-06    3842.576923
# 2016-07    3821.653846
# 2016-08    3793.653846
# 2016-09    3759.153846
# 2016-10    3730.384615
# ...

# %%
bronx_rent = nyc_rental_data[nyc_rental_data["CountyName"]=="Bronx"]
bronx_rent_mean = bronx_rent.drop(columns=["RegionID","RegionName","City","State","Metro","SizeRank","CountyName"]).mean()
bronx_rent_mean.dropna()
# Out:
# 2011-12    1566.380952
# 2012-01    1557.190476
# 2012-02    1548.714286
# 2012-03    1540.619048
# 2012-04    1546.238095
# 2012-05    1557.476190
# 2012-06    1572.333333
# 2012-07    1589.000000
# 2012-08    1611.904762
# 2012-09    1628.142857
# 2012-10    1627.714286
# 2012-11    1617.904762
# 2012-12    1612.761905
# 2013-01    1610.238095
# 2013-02    1607.666667
# 2013-03    1603.857143
# 2013-04    1610.809524
# 2013-05    1624.809524
# 2013-06    1638.476190
# 2013-07    1644.428571
# 2013-08    1646.904762
# 2013-09    1648.952381
# 2013-10    1653.190476
# 2013-11    1654.857143
# 2013-12    1658.761905
# 2014-01    1658.190476
# 2014-02    1656.761905
# 2014-03    1649.857143
# 2014-04    1648.809524
# 2014-05    1645.476190
#               ...
# 2016-02    1866.333333
# 2016-03    1863.285714
# 2016-04    1853.380952
# 2016-05    1844.380952
# 2016-06    1837.666667
# 2016-07    1838.333333
# 2016-08    1841.761905
# 2016-09    1846.904762
# 2016-10    1846.809524
# ...

# %%
queens_rent = nyc_rental_data[nyc_rental_data["CountyName"]=="Queens"]
queens_rent_mean = queens_rent.drop(columns=["RegionID","RegionName","City","State","Metro","SizeRank","CountyName"]).mean()
queens_rent_mean.dropna()
# Out:
# 2011-12    1682.081967
# 2012-01    1686.245902
# 2012-02    1693.540984
# 2012-03    1703.655738
# 2012-04    1711.672131
# 2012-05    1719.032787
# 2012-06    1726.655738
# 2012-07    1734.081967
# 2012-08    1736.180328
# 2012-09    1737.442623
# 2012-10    1740.934426
# 2012-11    1754.836066
# 2012-12    1770.901639
# 2013-01    1779.672131
# 2013-02    1784.491803
# 2013-03    1791.311475
# 2013-04    1797.311475
# 2013-05    1802.131148
# 2013-06    1803.377049
# 2013-07    1813.344262
# 2013-08    1833.360656
# 2013-09    1859.213115
# 2013-10    1885.918033
# 2013-11    1912.327869
# 2013-12    1942.295082
# 2014-01    1970.704918
# 2014-02    1988.065574
# 2014-03    1993.688525
# 2014-04    1993.344262
# 2014-05    1995.262295
#               ...
# 2016-02    2255.377049
# 2016-03    2256.409836
# 2016-04    2256.475410
# 2016-05    2255.049180
# 2016-06    2249.606557
# 2016-07    2250.524590
# 2016-08    2248.672131
# 2016-09    2252.393443
# 2016-10    2260.360656
# ...

# %%
staten_island_rent = nyc_rental_data[nyc_rental_data["CountyName"]=="Richmond"]
staten_island_rent_mean = staten_island_rent.drop(columns=["RegionID","RegionName","City","State","Metro","SizeRank","CountyName"]).mean()
staten_island_rent_mean.dropna()
# Out:
# 2010-11     910.789474
# 2010-12     911.368421
# 2011-01     910.000000
# 2011-02     910.500000
# 2011-03     909.000000
# 2011-04     886.315789
# 2011-05     854.105263
# 2011-06     817.210526
# 2011-07     801.815789
# 2011-08     793.421053
# 2011-09     789.236842
# 2011-10     786.052632
# 2011-11     784.368421
# 2011-12    1390.290698
# 2012-01    1385.500000
# 2012-02    1384.453488
# 2012-03    1383.255814
# 2012-04    1383.360465
# 2012-05    1384.069767
# 2012-06    1386.918605
# 2012-07    1384.744186
# 2012-08    1384.093023
# 2012-09    1384.686047
# 2012-10    1389.720930
# 2012-11    1396.081395
# 2012-12    1406.709302
# 2013-01    1422.081395
# 2013-02    1437.500000
# 2013-03    1446.116279
# 2013-04    1448.325581
#               ...
# 2016-02    1575.465116
# 2016-03    1569.511628
# 2016-04    1553.918605
# 2016-05    1554.558140
# 2016-06    1568.372093
# 2016-07    1590.023256
# 2016-08    1600.697674
# 2016-09    1604.162791
# 2016-10    1600.686047
# ...

# %%
brooklyn_rent = nyc_rental_data[nyc_rental_data["CountyName"]=="Kings"]
brooklyn_rent_mean = brooklyn_rent.drop(columns=["RegionID","RegionName","City","State","Metro","SizeRank","CountyName"]).mean()
brooklyn_rent_mean.dropna()
# Out:
# 2011-12    1790.687500
# 2012-01    1782.708333
# 2012-02    1776.916667
# 2012-03    1779.416667
# 2012-04    1791.625000
# 2012-05    1811.729167
# 2012-06    1840.958333
# 2012-07    1871.916667
# 2012-08    1902.875000
# 2012-09    1922.312500
# 2012-10    1935.687500
# 2012-11    1942.125000
# 2012-12    1949.500000
# 2013-01    1953.770833
# 2013-02    1952.895833
# 2013-03    1956.791667
# 2013-04    1967.562500
# 2013-05    1996.104167
# 2013-06    2026.270833
# 2013-07    2068.791667
# 2013-08    2098.645833
# 2013-09    2122.229167
# 2013-10    2123.812500
# 2013-11    2120.729167
# 2013-12    2116.541667
# 2014-01    2119.416667
# 2014-02    2130.312500
# 2014-03    2138.145833
# 2014-04    2149.104167
# 2014-05    2151.979167
#               ...
# 2016-02    2403.208333
# 2016-03    2400.291667
# 2016-04    2399.770833
# 2016-05    2406.916667
# 2016-06    2413.958333
# 2016-07    2425.020833
# 2016-08    2438.729167
# 2016-09    2450.020833
# 2016-10    2459.520833
# ...

# %%
print(manhattan_rent_mean.head())
print(bronx_rent_mean.head())
print(queens_rent_mean.head())
print(staten_island_rent_mean.head())
print(brooklyn_rent_mean.head())
# Out:
# 2010-11   NaN
# 2010-12   NaN
# 2011-01   NaN
# 2011-02   NaN
# 2011-03   NaN
# dtype: float64
# 2010-11   NaN
# 2010-12   NaN
# 2011-01   NaN
# 2011-02   NaN
# 2011-03   NaN
# dtype: float64
# 2010-11   NaN
# 2010-12   NaN
# 2011-01   NaN
# 2011-02   NaN
# 2011-03   NaN
# dtype: float64
# 2010-11    910.789474
# 2010-12    911.368421
# 2011-01    910.000000
# 2011-02    910.500000
# 2011-03    909.000000
# dtype: float64
# 2010-11   NaN
# 2010-12   NaN
# 2011-01   NaN
# 2011-02   NaN
# 2011-03   NaN
# dtype: float64

# %%
df = pd.DataFrame(manhattan_rent_mean,columns=['Average Manhattan rental price'])

# %%
df = df.join(pd.DataFrame(brooklyn_rent_mean,columns=['Average Brooklyn rental price']))

# %%
df = df.join(pd.DataFrame(bronx_rent_mean,columns=['Average Bronx rental price']))

# %%
df = df.join(pd.DataFrame(queens_rent_mean, columns=['Average Queens rental price']))

# %%
df = df.join(pd.DataFrame(staten_island_rent_mean, columns = ['Average Staten Island rental price']))

# %%
df = df.reset_index(drop=False)

# %%
df = df.rename(columns={"index":"Date"})

# %%
df
# Out:
#        Date  Average Manhattan rental price  Average Brooklyn rental price  \
# 0   2010-11                             NaN                            NaN
# 1   2010-12                             NaN                            NaN
# 2   2011-01                             NaN                            NaN
# 3   2011-02                             NaN                            NaN
# 4   2011-03                             NaN                            NaN
# 5   2011-04                             NaN                            NaN
# 6   2011-05                             NaN                            NaN
# 7   2011-06                             NaN                            NaN
# 8   2011-07                             NaN                            NaN
# 9   2011-08                             NaN                            NaN
# 10  2011-09                             NaN                            NaN
# ...

# %%
#df.merge(nyc_price_per_sqft, on='Date')

# %%
#df.join(pd.DataFrame(nyc_price_per_sqft,column=['Date']))

# %%
df.dropna()
df_reset = df.reset_index()

# %%
df_date = df_reset['Date'].str.split('-',expand=True)

# %%
nyc_rental = df_reset.join(df_date, how='inner')

# %%
nyc_rental1 = nyc_rental.dropna()

# %%
nyc_rental1 = nyc_rental1.drop(columns=['index','Date'])

# %%
df = nyc_rental1.rename(columns={0:'Year'})

# %%
df['Year'] = df.Year.astype(int)

# %%
df_by_year = df.groupby(['Year']).mean()

# %%
df_by_year
# Out:
#       Average Manhattan rental price  Average Brooklyn rental price  \
# Year
# 2011                     3034.115385                    1790.687500
# 2012                     3075.647436                    1858.980903
# 2013                     3186.294872                    2042.012153
# 2014                     3421.733974                    2194.678819
# 2015                     3786.842949                    2333.333333
# 2016                     3778.961538                    2427.928819
# 2017                     3670.596154                    2458.456597
# 2018                     3586.884615                    2415.130952
#
#       Average Bronx rental price  Average Queens rental price  \
# Year
# 2011                 1566.380952                  1682.081967
# 2012                 1584.166667                  1726.265027
# 2013                 1633.579365                  1833.729508
# 2014                 1677.857143                  2028.334699
# ...

# %%
df_by_year_short = df_by_year.loc[df_by_year.index.isin(['2012','2013','2014','2015','2016','2017'])]
df_by_year_short.index
# Out:
# Int64Index([2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name='Year')

# %%
df_by_year_short.plot(kind='line', title="RENTAL PRICES PER BOROUGH", legend=None).set(xlabel='Years', ylabel='Average Rental Prices')

plt.xticks(df_by_year_short.index.astype(int), list(df_by_year_short.index) )
#df_by_year_short.set(xlabel='Years')
# Out:
# ([<matplotlib.axis.XTick at 0x17125cf4198>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
df_by_year_short.plot(kind='bar', title="RENTAL PRICES PER BOROUGH").set(xlabel='Years', ylabel='Average Rental Prices', ylim=(0, 6500))
df_by_year_short.plot?

# %%
plt.savefig("rentals_per_borough.png")

# %%
plt.close()
